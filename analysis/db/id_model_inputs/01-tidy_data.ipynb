# %%
import re

import pandas as pd
from pyprojroot import here

# %%
# about 40 seconds - 2 minutes depending on system resources to load
df = pd.read_json(here("./data/db/final/kaggle/id_model_inputs/03-normalized_columns.json.gzip"), compression="gzip")

# %%
#df.info(memory_usage="deep")

# %%
#df.drop(['text', 'sent_set', 'found_sent', 'found_count'], axis='columns', inplace=True)

# %%
for col in df.filter(regex='num_authors|ct-').columns:
    print(col)
    df[col] = df[col].astype(pd.Int16Dtype())
# Out:
# num_authors
# ct-incubation_period
# ct-latent_period
# ct-asymptomatic_proportion
# ct-case_fatality_ratio
# ct-recovery_rate
# ct-infectiousness_period
# ct-case_fatality_rate
# ct-hospitalized_proportion
# ct-asymptomatic_fraction
# ct-hospitalized_fraction
# ct-asymptomatic_ratio

# %%
for col in df.filter(regex='has-').columns:
    print(col)
    df[col] = df[col].astype('bool')
# Out:
# has-incubation_period
# has-latent_period
# has-asymptomatic_proportion
# has-case_fatality_ratio
# has-recovery_rate
# has-infectiousness_period
# has-case_fatality_rate
# has-hospitalized_proportion
# has-asymptomatic_fraction
# has-hospitalized_fraction
# has-asymptomatic_ratio

# %%
df["title"] = df["title"].astype('string')

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5928 entries, 0 to 5927
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         5928 non-null   int64
#  1   pid                           5928 non-null   object
#  2   num_authors                   5928 non-null   Int16
#  3   title                         5928 non-null   string
#  4   text                          5928 non-null   object
#  5   text_sent_lower               5928 non-null   object
#  6   sent_set                      5928 non-null   object
#  7   found_terms                   5928 non-null   object
#  8   found_sent_idx                5928 non-null   object
#  9   found_sent                    5928 non-null   object
#  10  found_count                   5928 non-null   object
#  11  has-incubation_period         5928 non-null   bool
#  12  has-latent_period             5928 non-null   bool
#  13  has-asymptomatic_proportion   5928 non-null   bool
#  14  has-case_fatality_ratio       5928 non-null   bool
#  15  has-recovery_rate             5928 non-null   bool
#  16  has-infectiousness_period     5928 non-null   bool
#  17  has-case_fatality_rate        5928 non-null   bool
#  18  has-hospitalized_proportion   5928 non-null   bool
#  19  has-asymptomatic_fraction     5928 non-null   bool
#  20  has-hospitalized_fraction     5928 non-null   bool
#  21  has-asymptomatic_ratio        5928 non-null   bool
#  22  ct-incubation_period          3574 non-null   Int16
#  23  ct-latent_period              368 non-null    Int16
#  24  ct-asymptomatic_proportion    350 non-null    Int16
#  25  ct-case_fatality_ratio        185 non-null    Int16
#  26  ct-recovery_rate              783 non-null    Int16
#  27  ct-infectiousness_period      148 non-null    Int16
#  28  ct-case_fatality_rate         1436 non-null   Int16
#  29  ct-hospitalized_proportion    226 non-null    Int16
#  30  ct-asymptomatic_fraction      83 non-null     Int16
#  31  ct-hospitalized_fraction      33 non-null     Int16
#  32  ct-asymptomatic_ratio         77 non-null     Int16
#  33  idx-incubation_period         3574 non-null   object
#  34  idx-latent_period             368 non-null    object
#  35  idx-asymptomatic_proportion   350 non-null    object
#  36  idx-case_fatality_ratio       185 non-null    object
#  37  idx-recovery_rate             783 non-null    object
#  38  idx-infectiousness_period     148 non-null    object
#  39  idx-case_fatality_rate        1436 non-null   object
#  40  idx-hospitalized_proportion   226 non-null    object
#  41  idx-asymptomatic_fraction     83 non-null     object
#  42  idx-hospitalized_fraction     33 non-null     object
#  43  idx-asymptomatic_ratio        77 non-null     object
#  44  sent-incubation_period        3574 non-null   object
#  45  sent-latent_period            368 non-null    object
#  46  sent-asymptomatic_proportion  350 non-null    object
#  47  sent-case_fatality_ratio      185 non-null    object
#  48  sent-recovery_rate            783 non-null    object
#  49  sent-infectiousness_period    148 non-null    object
#  50  sent-case_fatality_rate       1436 non-null   object
#  51  sent-hospitalized_proportion  226 non-null    object
#  52  sent-asymptomatic_fraction    83 non-null     object
#  53  sent-hospitalized_fraction    33 non-null     object
#  54  sent-asymptomatic_ratio       77 non-null     object
# dtypes: Int16(12), bool(11), int64(1), object(30), string(1)
# memory usage: 438.4 MB

# %%
covid_papers = [
    "PMC7121484", # Early Transmission Dynamics in Wuhan
    "PMC7186508" # To mask or not to mask
]
df[df.pid.isin(covid_papers)].filter(like="sent-")
# Out:
#                                  sent-incubation_period sent-latent_period  \
# 2719  [[the incubation period distribution (i.e., th...               None
# 4528  [[additionally, η accounts for the relative in...               None
#
#                            sent-asymptomatic_proportion  \
# 2719                                               None
# 4528  [[unsurprisingly, the greater the proportion o...
#
#      sent-case_fatality_ratio  \
# 2719                     None
# 4528                     None
#
#                                      sent-recovery_rate  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#                              sent-infectiousness_period  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#      sent-case_fatality_rate sent-hospitalized_proportion  \
# 2719                    None                         None
# 4528                    None                         None
#
#                              sent-asymptomatic_fraction  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#                              sent-hospitalized_fraction  \
# 2719                                               None
# 4528  [[we assume that some fraction of symptomatic ...
#
#      sent-asymptomatic_ratio
# 2719                    None
# 4528                    None

# %% [markdown]
# ## Which papers contain which KWs

# %%
sent_cols = df.columns[df.columns.str.contains("sent-")]
sent_cols
# Out:
# Index(['sent-incubation_period', 'sent-latent_period',
#        'sent-asymptomatic_proportion', 'sent-case_fatality_ratio',
#        'sent-recovery_rate', 'sent-infectiousness_period',
#        'sent-case_fatality_rate', 'sent-hospitalized_proportion',
#        'sent-asymptomatic_fraction', 'sent-hospitalized_fraction',
#        'sent-asymptomatic_ratio'],
#       dtype='object')

# %%
sent_bool = df[sent_cols].astype(bool)
sent_bool
# Out:
#       sent-incubation_period  sent-latent_period  \
# 0                       True               False
# 1                       True               False
# 2                      False                True
# 3                      False               False
# 4                       True               False
# ...                      ...                 ...
# 5923                   False                True
# 5924                    True               False
# 5925                   False                True
# 5926                    True               False
# 5927                    True               False
#
#       sent-asymptomatic_proportion  sent-case_fatality_ratio  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# 3                             True                     False
# 4                            False                     False
# ...                            ...                       ...
# 5923                         False                     False
# 5924                         False                     False
# 5925                         False                     False
# 5926                         False                     False
# 5927                         False                     False
#
#       sent-recovery_rate  sent-infectiousness_period  sent-case_fatality_rate  \
# 0                  False                       False                    False
# 1                  False                       False                    False
# 2                  False                       False                    False
# 3                  False                       False                    False
# 4                  False                       False                    False
# ...                  ...                         ...                      ...
# 5923               False                       False                    False
# 5924                True                       False                    False
# 5925                True                       False                    False
# 5926               False                       False                    False
# 5927               False                       False                    False
#
#       sent-hospitalized_proportion  sent-asymptomatic_fraction  \
# 0                            False                       False
# 1                            False                       False
# 2                            False                       False
# 3                            False                       False
# 4                            False                       False
# ...                            ...                         ...
# 5923                         False                       False
# 5924                         False                       False
# 5925                         False                       False
# 5926                         False                       False
# 5927                         False                       False
#
#       sent-hospitalized_fraction  sent-asymptomatic_ratio
# 0                          False                    False
# 1                          False                    False
# 2                          False                    False
# 3                          False                    False
# 4                          False                    False
# ...                          ...                      ...
# 5923                       False                    False
# 5924                       False                    False
# 5925                       False                    False
# 5926                       False                    False
# 5927                       False                    False
#
# [5928 rows x 11 columns]

# %%
sent_bool['num_matches'] = sent_bool.apply(sum, axis=1)

# %%
sent_bool['num_matches'].value_counts()
# Out:
# 1    4898
# 2     803
# 3     169
# 4      43
# 5      11
# 6       3
# 7       1
# Name: num_matches, dtype: int64

# %%
num_sent_matches = sent_bool.apply(sum, axis=1).value_counts(dropna=False)
num_sent_matches
# Out:
# 2     4898
# 4      803
# 6      169
# 8       43
# 10      11
# 12       3
# 14       1
# dtype: int64

# %%
len(sent_bool)
# Out:
# 5928

# %%
num_sent_matches.sum()
# Out:
# 5928

# %%
counts = sent_bool.groupby(list(sent_cols))['num_matches'].sum()

# %%
count_df = pd.DataFrame(counts, dtype=int)
count_df.columns = ["count"]
count_df = count_df.reset_index()
count_df['contain_ct'] = count_df.filter(like='sent-').apply(sum, axis=1)

# %%
counts = count_df.sort_values(by=["count"], ascending=False)

# %%
def color_pos(val):
    color = 'red' if val is True else 'grey'
    return 'color: %s' % color

# %%
counts.style.applymap(color_pos)
# Out:
# <style  type="text/css" >
#     #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col0 {
#             color:  red;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col1 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col2 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col3 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col4 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col5 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col6 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col7 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col8 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col9 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col10 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col11 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow0_col12 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col0 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col1 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col2 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col3 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col4 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col5 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col6 {
#             color:  red;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col7 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col8 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col9 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col10 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col11 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow1_col12 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col0 {
#             color:  red;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col1 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col2 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col3 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col4 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col5 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col6 {
#             color:  red;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col7 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col8 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col9 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col10 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col11 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow2_col12 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col0 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col1 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col2 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col3 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col4 {
#             color:  red;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col5 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col6 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col7 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col8 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col9 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col10 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col11 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow3_col12 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col0 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col1 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col2 {
#             color:  red;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col3 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col4 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col5 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col6 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col7 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col8 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col9 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col10 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col11 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow4_col12 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col0 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col1 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col2 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col3 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col4 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col5 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col6 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col7 {
#             color:  red;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col8 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col9 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col10 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col11 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow5_col12 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col0 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col1 {
#             color:  red;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col2 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col3 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col4 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col5 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col6 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col7 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col8 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acrow6_col9 {
#             color:  grey;
#         }    #T_7d4bfb44_cc7a_11ea_ba39_5cf3709b90acr

# %%
count_df.sort_values(['contain_ct'] + sent_cols.tolist()).style.applymap(color_pos)
# Out:
# <style  type="text/css" >
#     #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col0 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col1 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col2 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col3 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col4 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col5 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col6 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col7 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col8 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col9 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col10 {
#             color:  red;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col11 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow0_col12 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col0 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col1 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col2 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col3 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col4 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col5 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col6 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col7 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col8 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col9 {
#             color:  red;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col10 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col11 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow1_col12 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col0 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col1 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col2 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col3 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col4 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col5 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col6 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col7 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col8 {
#             color:  red;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col9 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col10 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col11 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow2_col12 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col0 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col1 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col2 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col3 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col4 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col5 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col6 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col7 {
#             color:  red;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col8 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col9 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col10 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col11 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow3_col12 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col0 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col1 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col2 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col3 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col4 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col5 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col6 {
#             color:  red;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col7 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col8 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col9 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col10 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col11 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow4_col12 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col0 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col1 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col2 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col3 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col4 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col5 {
#             color:  red;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col6 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col7 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col8 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col9 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col10 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col11 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow5_col12 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col0 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col1 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col2 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col3 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col4 {
#             color:  red;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col5 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col6 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col7 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col8 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90acrow6_col9 {
#             color:  grey;
#         }    #T_7e2b37d1_cc7a_11ea_beb5_5cf3709b90ac

# %%
7263-5928
# Out:
# 1335

# %%
counts["count"].sum()
# Out:
# 7263

# %%
len(df.pid.unique())
# Out:
# 5928

# %%
sent_long = df.filter(regex="pid|sent-").melt(id_vars='pid')
sent_long
# Out:
#               pid                 variable  \
# 0      PMC1074749   sent-incubation_period
# 1      PMC1090610   sent-incubation_period
# 2      PMC1181873   sent-incubation_period
# 3      PMC1215526   sent-incubation_period
# 4      PMC1247620   sent-incubation_period
# ...           ...                      ...
# 65203  PMC7298926  sent-asymptomatic_ratio
# 65204  PMC7299143  sent-asymptomatic_ratio
# 65205  PMC7299147  sent-asymptomatic_ratio
# 65206  PMC7299369  sent-asymptomatic_ratio
# 65207  PMC7299399  sent-asymptomatic_ratio
#
#                                                    value
# 0      [[after the mixture was heated to 99°c for 4 m...
# 1      [[the diagnosis module is designed to generate...
# 2                                                   None
# 3                                                   None
# 4      [[a 5-day incubation period, consistent with a...
# ...                                                  ...
# 65203                                               None
# 65204                                               None
# 65205                                               None
# 65206                                               None
# 65207                                               None
#
# [65208 rows x 3 columns]

# %%
# # this should match value above
# means "extra" papers is becuase some papers contain multiple sentence matches
sent_long.loc[sent_long['value'].astype(bool)].pid.duplicated().sum()
# Out:
# 1335

# %% [markdown]
# ## Filter on covid19 related terms

# %%
covid_papers
# Out:
# ['PMC7121484', 'PMC7186508']

# %%
df[df.pid.isin(covid_papers)]
# Out:
#       index         pid  num_authors  \
# 2719     49  PMC7121484           45
# 4528     28  PMC7186508            8
#
#                                                   title  \
# 2719  Early Transmission Dynamics in Wuhan, China, o...
# 4528  To mask or not to mask: Modeling the potential...
#
#                                                    text  \
# 2719  The earliest cases were identified through the...
# 4528  Under the ongoing COVID-19 pandemic (caused by...
#
#                                         text_sent_lower  \
# 2719  [the earliest cases were identified through th...
# 4528  [under the ongoing covid-19 pandemic (caused b...
#
#                                                sent_set  \
# 2719  [[pathogen, through, days, for, to, without, )...
# 4528  [[us, as, prevention, are, general, although, ...
#
#                                             found_terms  \
# 2719                    {'has-incubation_period': True}
# 4528  {'has-incubation_period': True, 'has-infectiou...
#
#                                          found_sent_idx  \
# 2719        {'idx-incubation_period': [24, 28, 40, 63]}
# 4528  {'idx-incubation_period': [58], 'idx-infectiou...
#
#                                              found_sent  ...  \
# 2719  {'sent-incubation_period': [['the incubation p...  ...
# 4528  {'sent-incubation_period': [['additionally, η ...  ...
#
#      sent-latent_period                       sent-asymptomatic_proportion  \
# 2719               None                                               None
# 4528               None  [[unsurprisingly, the greater the proportion o...
#
#       sent-case_fatality_ratio  \
# 2719                      None
# 4528                      None
#
#                                      sent-recovery_rate  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#                              sent-infectiousness_period  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#       sent-case_fatality_rate  sent-hospitalized_proportion  \
# 2719                     None                          None
# 4528                     None                          None
#
#                              sent-asymptomatic_fraction  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#                              sent-hospitalized_fraction  \
# 2719                                               None
# 4528  [[we assume that some fraction of symptomatic ...
#
#       sent-asymptomatic_ratio
# 2719                     None
# 4528                     None
#
# [2 rows x 55 columns]

# %%
df[df.pid.isin(covid_papers)].text_sent_lower.str.get(0) # same as regex filtering method
# Out:
# 2719    the earliest cases were identified through the...
# 4528    under the ongoing covid-19 pandemic (caused by...
# Name: text_sent_lower, dtype: object

# %%
filter_words_lower_regex = [
    r".*covid\s?-?\s?19.*", # covid-19
    r".*sars-?cov-?2.*",    # sars-cov-2
    r".*ncov.*",            # ncov
    r".*coronavirus.*",     # coronavirus
]
pattern = "|".join(filter_words_lower_regex)
pattern
# Out:
# '.*covid\\s?-?\\s?19.*|.*sars-?cov-?2.*|.*ncov.*|.*coronavirus.*'

# %%
r = re.compile(pattern)
r
# Out:
# re.compile(r'.*covid\s?-?\s?19.*|.*sars-?cov-?2.*|.*ncov.*|.*coronavirus.*',
# re.UNICODE)

# %%
df.shape
# Out:
# (5928, 55)

# %%
df.columns
# Out:
# Index(['index', 'pid', 'num_authors', 'title', 'text', 'text_sent_lower',
#        'sent_set', 'found_terms', 'found_sent_idx', 'found_sent',
#        'found_count', 'has-incubation_period', 'has-latent_period',
#        'has-asymptomatic_proportion', 'has-case_fatality_ratio',
#        'has-recovery_rate', 'has-infectiousness_period',
#        'has-case_fatality_rate', 'has-hospitalized_proportion',
#        'has-asymptomatic_fraction', 'has-hospitalized_fraction',
#        'has-asymptomatic_ratio', 'ct-incubation_period', 'ct-latent_period',
#        'ct-asymptomatic_proportion', 'ct-case_fatality_ratio',
#        'ct-recovery_rate', 'ct-infectiousness_period', 'ct-case_fatality_rate',
#        'ct-hospitalized_proportion', 'ct-asymptomatic_fraction',
#        'ct-hospitalized_fraction', 'ct-asymptomatic_ratio',
#        'idx-incubation_period', 'idx-latent_period',
#        'idx-asymptomatic_proportion', 'idx-case_fatality_ratio',
#        'idx-recovery_rate', 'idx-infectiousness_period',
#        'idx-case_fatality_rate', 'idx-hospitalized_proportion',
#        'idx-asymptomatic_fraction', 'idx-hospitalized_fraction',
#        'idx-asymptomatic_ratio', 'sent-incubation_period',
#        'sent-latent_period', 'sent-asymptomatic_proportion',
#        'sent-case_fatality_ratio', 'sent-recovery_rate',
#        'sent-infectiousness_period', 'sent-case_fatality_rate',
#        'sent-hospitalized_proportion', 'sent-asymptomatic_fraction',
#        'sent-hospitalized_fraction', 'sent-asymptomatic_ratio'],
#       dtype='object')

# %%
from tqdm import tqdm

# %%
tqdm.pandas(desc="sentence")

matched_papers = []
for pidx, paper_text in enumerate(tqdm(df.text_sent_lower)):
    for sidx, sentence in enumerate(paper_text):
        if r.match(sentence.lower()):
            #print(f"paper: {pidx}, sentence: {sidx}")
            matched_papers.append(df.iloc[pidx])
            break
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 5928/5928 [00:07<00:00, 836.05it/s]

# %%
len(matched_papers)
# Out:
# 4054

# %%
# look for pattern matches all lower case
has_covid_term = df['text_sent_lower'].apply(lambda x: any([True for sent in x if r.match(sent.lower())]))

# %%
covid_kw_sent = df[has_covid_term]

# %%
covid_kw_sent.shape
# Out:
# (4054, 55)

# %%
covid_kw_sent[covid_kw_sent.pid.isin(covid_papers)]
# Out:
#       index         pid  num_authors  \
# 2719     49  PMC7121484           45
# 4528     28  PMC7186508            8
#
#                                                   title  \
# 2719  Early Transmission Dynamics in Wuhan, China, o...
# 4528  To mask or not to mask: Modeling the potential...
#
#                                                    text  \
# 2719  The earliest cases were identified through the...
# 4528  Under the ongoing COVID-19 pandemic (caused by...
#
#                                         text_sent_lower  \
# 2719  [the earliest cases were identified through th...
# 4528  [under the ongoing covid-19 pandemic (caused b...
#
#                                                sent_set  \
# 2719  [[pathogen, through, days, for, to, without, )...
# 4528  [[us, as, prevention, are, general, although, ...
#
#                                             found_terms  \
# 2719                    {'has-incubation_period': True}
# 4528  {'has-incubation_period': True, 'has-infectiou...
#
#                                          found_sent_idx  \
# 2719        {'idx-incubation_period': [24, 28, 40, 63]}
# 4528  {'idx-incubation_period': [58], 'idx-infectiou...
#
#                                              found_sent  ...  \
# 2719  {'sent-incubation_period': [['the incubation p...  ...
# 4528  {'sent-incubation_period': [['additionally, η ...  ...
#
#      sent-latent_period                       sent-asymptomatic_proportion  \
# 2719               None                                               None
# 4528               None  [[unsurprisingly, the greater the proportion o...
#
#       sent-case_fatality_ratio  \
# 2719                      None
# 4528                      None
#
#                                      sent-recovery_rate  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#                              sent-infectiousness_period  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#       sent-case_fatality_rate  sent-hospitalized_proportion  \
# 2719                     None                          None
# 4528                     None                          None
#
#                              sent-asymptomatic_fraction  \
# 2719                                               None
# 4528  [[additionally, η accounts for the relative in...
#
#                              sent-hospitalized_fraction  \
# 2719                                               None
# 4528  [[we assume that some fraction of symptomatic ...
#
#       sent-asymptomatic_ratio
# 2719                     None
# 4528                     None
#
# [2 rows x 55 columns]

# %%
covid_kw_sent[covid_kw_sent.pid.isin(covid_papers)].filter(like="sent-incu").iloc[0][0]
# Out:
# [['the incubation period distribution (i.e., the time delay from infection to illness onset) was estimated by fitting a log-normal distribution to data on exposure histories and onset dates in a subset of cases with detailed information available.',
#   'we used an informative prior distribution for the serial interval based on the serial interval of sars with a mean of 8.4 and a standard deviation of 3.8.11\nanalyses of the incubation period, serial interval, growth rate, and r0 were performed with the use of matlab software (mathworks).',
#   'we examined data on exposures among 10 confirmed cases, and we estimated the mean incubation period to be 5.2 days (95% confidence interval [ci], 4.1 to 7.0); the 95th percentile of the distribution was 12.5 days (95% ci, 9.2 to 18) (figure 2a).',
#   'our preliminary estimate of the incubation period distribution provides important evidence to support a 14-day medical observation period or quarantine for exposed persons.']]

# %% [markdown]
# ## explode sentences

# %%
covid_kw_sent.pid.duplicated().any() # should be false
# Out:
# False

# %%
sent_cols.to_list()
# Out:
# ['sent-incubation_period',
#  'sent-latent_period',
#  'sent-asymptomatic_proportion',
#  'sent-case_fatality_ratio',
#  'sent-recovery_rate',
#  'sent-infectiousness_period',
#  'sent-case_fatality_rate',
#  'sent-hospitalized_proportion',
#  'sent-asymptomatic_fraction',
#  'sent-hospitalized_fraction',
#  'sent-asymptomatic_ratio']

# %%
covid_kw_sent.columns
# Out:
# Index(['index', 'pid', 'num_authors', 'title', 'text', 'text_sent_lower',
#        'sent_set', 'found_terms', 'found_sent_idx', 'found_sent',
#        'found_count', 'has-incubation_period', 'has-latent_period',
#        'has-asymptomatic_proportion', 'has-case_fatality_ratio',
#        'has-recovery_rate', 'has-infectiousness_period',
#        'has-case_fatality_rate', 'has-hospitalized_proportion',
#        'has-asymptomatic_fraction', 'has-hospitalized_fraction',
#        'has-asymptomatic_ratio', 'ct-incubation_period', 'ct-latent_period',
#        'ct-asymptomatic_proportion', 'ct-case_fatality_ratio',
#        'ct-recovery_rate', 'ct-infectiousness_period', 'ct-case_fatality_rate',
#        'ct-hospitalized_proportion', 'ct-asymptomatic_fraction',
#        'ct-hospitalized_fraction', 'ct-asymptomatic_ratio',
#        'idx-incubation_period', 'idx-latent_period',
#        'idx-asymptomatic_proportion', 'idx-case_fatality_ratio',
#        'idx-recovery_rate', 'idx-infectiousness_period',
#        'idx-case_fatality_rate', 'idx-hospitalized_proportion',
#        'idx-asymptomatic_fraction', 'idx-hospitalized_fraction',
#        'idx-asymptomatic_ratio', 'sent-incubation_period',
#        'sent-latent_period', 'sent-asymptomatic_proportion',
#        'sent-case_fatality_ratio', 'sent-recovery_rate',
#        'sent-infectiousness_period', 'sent-case_fatality_rate',
#        'sent-hospitalized_proportion', 'sent-asymptomatic_fraction',
#        'sent-hospitalized_fraction', 'sent-asymptomatic_ratio'],
#       dtype='object')

# %%
non_sent_cols = ["pid", "title"]#, "publish_time_dt", 'doi', 'url']
non_sent_cols
# Out:
# ['pid', 'title']

# %%
covid_kw_sent_subset = covid_kw_sent[non_sent_cols + sent_cols.to_list()]
covid_kw_sent_subset
# Out:
#              pid                                              title  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...
# 3     PMC1215526  Macrophages and cytokines in the early defence...
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 6     PMC1276795  A simple and rapid approach for screening of S...
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...
# ...          ...                                                ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...
# 5924  PMC7299143  Significance of geographical factors to the CO...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...
#
#                                  sent-incubation_period  \
# 0     [[after the mixture was heated to 99°c for 4 m...
# 3                                                  None
# 5     [[after an incubation period from 2 to 10 days...
# 6     [[the thermal profile consists of an initial i...
# 8                                                  None
# ...                                                 ...
# 5923                                               None
# 5924  [[this contact transmissible disease has an av...
# 5925                                               None
# 5926  [[in most patients, the median time of incubat...
# 5927  [[the severity of disease in patients depends ...
#
#                                      sent-latent_period  \
# 0                                                  None
# 3                                                  None
# 5                                                  None
# 6                                                  None
# 8                                                  None
# ...                                                 ...
# 5923  [[another interesting concentration is related...
# 5924                                               None
# 5925  [[for an asymptomatically infected individual,...
# 5926                                               None
# 5927                                               None
#
#                            sent-asymptomatic_proportion  \
# 0                                                  None
# 3     [[seropositivity to hsv-1 does not render any ...
# 5                                                  None
# 6                                                  None
# 8                                                  None
# ...                                                 ...
# 5923                                               None
# 5924                                               None
# 5925                                               None
# 5926                                               None
# 5927                                               None
#
#                                sent-case_fatality_ratio  \
# 0                                                  None
# 3                                                  None
# 5                                                  None
# 6                                                  None
# 8     [[more recently, a coronavirus has been identi...
# ...                                                 ...
# 5923                                               None
# 5924                                               None
# 5925                                               None
# 5926                                               None
# 5927                                               None
#
#                                      sent-recovery_rate  \
# 0                                                  None
# 3                                                  None
# 5                                                  None
# 6                                                  None
# 8                                                  None
# ...                                                 ...
# 5923                                               None
# 5924  [[these workers did not observe any noticeable...
# 5925  [[first, we explore the impact of recovery rat...
# 5926                                               None
# 5927                                               None
#
#      sent-infectiousness_period sent-case_fatality_rate  \
# 0                          None                    None
# 3                          None                    None
# 5                          None                    None
# 6                          None                    None
# 8                          None                    None
# ...                         ...                     ...
# 5923                       None                    None
# 5924                       None                    None
# 5925                       None                    None
# 5926                       None                    None
# 5927                       None                    None
#
#      sent-hospitalized_proportion sent-asymptomatic_fraction  \
# 0                            None                       None
# 3                            None                       None
# 5                            None                       None
# 6                            None                       None
# 8                            None                       None
# ...                           ...                        ...
# 5923                         None                       None
# 5924                         None                       None
# 5925                         None                       None
# 5926                         None                       None
# 5927                         None                       None
#
#      sent-hospitalized_fraction sent-asymptomatic_ratio
# 0                          None                    None
# 3                          None                    None
# 5                          None                    None
# 6                          None                    None
# 8                          None                    None
# ...                         ...                     ...
# 5923                       None                    None
# 5924                       None                    None
# 5925                       None                    None
# 5926                       None                    None
# 5927                       None                    None
#
# [4054 rows x 13 columns]

# %%
non_sent_cols + [sent_cols[0]]
# Out:
# ['pid', 'title', 'sent-incubation_period']

# %%
covid_kw_sent_subset[non_sent_cols + [sent_cols[0]]].explode(sent_cols[0]).explode(sent_cols[0])
# Out:
#              pid                                              title  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...
# 3     PMC1215526  Macrophages and cytokines in the early defence...
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 6     PMC1276795  A simple and rapid approach for screening of S...
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...
# ...          ...                                                ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...
# 5924  PMC7299143  Significance of geographical factors to the CO...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...
#
#                                  sent-incubation_period
# 0     after the mixture was heated to 99°c for 4 min...
# 3                                                  None
# 5     after an incubation period from 2 to 10 days, ...
# 6     the thermal profile consists of an initial inc...
# 8                                                  None
# ...                                                 ...
# 5923                                               None
# 5924  this contact transmissible disease has an aver...
# 5925                                               None
# 5926  in most patients, the median time of incubatio...
# 5927  the severity of disease in patients depends ma...
#
# [6703 rows x 3 columns]

# %%
tqdm.pandas(desc="explode")

exploded_df_list = []

for idx, sc in enumerate(tqdm(sent_cols)):
    print(idx, sc)
    exploded = covid_kw_sent_subset[non_sent_cols + [sc]].explode(sc).explode(sc)
    exploded = exploded.rename({sc: "sentence"}, axis='columns')
    exploded['match_type'] = sc
    display(exploded)
    exploded_df_list.append(exploded)
# Out:
# C:\Users\Danie\miniconda3\envs\db_covid19\lib\site-packages\tqdm\std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
#   0%|                                                                                           | 0/11 [00:00<?, ?it/s]
# 0 sent-incubation_period
#              pid                                              title  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...
# 3     PMC1215526  Macrophages and cytokines in the early defence...
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 6     PMC1276795  A simple and rapid approach for screening of S...
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...
# ...          ...                                                ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...
# 5924  PMC7299143  Significance of geographical factors to the CO...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...
#
#                                                sentence  \
# 0     after the mixture was heated to 99°c for 4 min...
# 3                                                  None
# 5     after an incubation period from 2 to 10 days, ...
# 6     the thermal profile consists of an initial inc...
# 8                                                  None
# ...                                                 ...
# 5923                                               None
# 5924  this contact transmissible disease has an aver...
# 5925                                               None
# 5926  in most patients, the median time of incubatio...
# 5927  the severity of disease in patients depends ma...
#
#                   match_type
# 0     sent-incubation_period
# 3     sent-incubation_period
# 5     sent-incubation_period
# 6     sent-incubation_period
# 8     sent-incubation_period
# ...                      ...
# 5923  sent-incubation_period
# 5924  sent-incubation_period
# 5925  sent-incubation_period
# 5926  sent-incubation_period
# 5927  sent-incubation_period
#
# [6703 rows x 4 columns]
# 1 sent-latent_period
#              pid                                              title  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...
# 3     PMC1215526  Macrophages and cytokines in the early defence...
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 6     PMC1276795  A simple and rapid approach for screening of S...
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...
# ...          ...                                                ...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...
#
#                                                sentence          match_type
# 0                                                  None  sent-latent_period
# 3                                                  None  sent-latent_period
# 5                                                  None  sent-latent_period
# 6                                                  None  sent-latent_period
# 8                                                  None  sent-latent_period
# ...                                                 ...                 ...
# 5925  4, we realize that the net increment rate of s...  sent-latent_period
# 5925  and throughout the spread of covid-19 in wuhan...  sent-latent_period
# 5925  thus, the opinion that the latent period can b...  sent-latent_period
# 5926                                               None  sent-latent_period
# 5927                                               None  sent-latent_period
#
# [4177 rows x 4 columns]
#  18%|███████████████                                                                    | 2/11 [00:00<00:00, 15.75it/s]
# 2 sent-asymptomatic_proportion
#              pid                                              title  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...
# 3     PMC1215526  Macrophages and cytokines in the early defence...
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 6     PMC1276795  A simple and rapid approach for screening of S...
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...
# ...          ...                                                ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...
# 5924  PMC7299143  Significance of geographical factors to the CO...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...
#
#                                                sentence  \
# 0                                                  None
# 3     seropositivity to hsv-1 does not render any pr...
# 5                                                  None
# 6                                                  None
# 8                                                  None
# ...                                                 ...
# 5923                                               None
# 5924                                               None
# 5925                                               None
# 5926                                               None
# 5927                                               None
#
#                         match_type
# 0     sent-asymptomatic_proportion
# 3     sent-asymptomatic_proportion
# 5     sent-asymptomatic_proportion
# 6     sent-asymptomatic_proportion
# 8     sent-asymptomatic_proportion
# ...                            ...
# 5923  sent-asymptomatic_proportion
# 5924  sent-asymptomatic_proportion
# 5925  sent-asymptomatic_proportion
# 5926  sent-asymptomatic_proportion
# 5927  sent-asymptomatic_proportion
#
# [4188 rows x 4 columns]
# 3 sent-case_fatality_ratio
#              pid                                              title  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...
# 3     PMC1215526  Macrophages and cytokines in the early defence...
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 6     PMC1276795  A simple and rapid approach for screening of S...
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...
# ...          ...                                                ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...
# 5924  PMC7299143  Significance of geographical factors to the CO...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...
#
#                                                sentence  \
# 0                                                  None
# 3                                                  None
# 5                                                  None
# 6                                                  None
# 8     more recently, a coronavirus has been identifi...
# ...                                                 ...
# 5923                                               None
# 5924                                               None
# 5925                                               None
# 5926                                               None
# 5927                                               None
#
#                     match_type
# 0     sent-case_fatality_ratio
# 3     sent-case_fatality_ratio
# 5     sent-case_fatality_ratio
# 6     sent-case_fatality_ratio
# 8     sent-case_fatality_ratio
# ...                        ...
# 5923  sent-case_fatality_ratio
# 5924  sent-case_fatality_ratio
# 5925  sent-case_fatality_ratio
# 5926  sent-case_fatality_ratio
# 5927  sent-case_fatality_ratio
#
# [4134 rows x 4 columns]
#  36%|██████████████████████████████▏                                                    | 4/11 [00:00<00:00, 15.90it/s]
# 4 sent-recovery_rate
#              pid                                              title  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...
# 3     PMC1215526  Macrophages and cytokines in the early defence...
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 6     PMC1276795  A simple and rapid approach for screening of S...
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...
# ...          ...                                                ...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5925  PMC7299147  A new SAIR model on complex networks for analy...
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...
#
#                                                sentence          match_type
# 0                                                  None  sent-recovery_rate
# 3                                                  None  sent-recovery_rate
# 5                                                  None  sent-recovery_rate
# 6                                                  None  sent-recovery_rate
# 8                                                  None  sent-recovery_rate
# ...                                                 ...                 ...
# 5925  these indicate that increasing the recovery ra...  sent-recovery_rate
# 5925  in summary, the best way to curb the spread of...  sent-recovery_rate
# 5925  increasing the recovery rate and the removed r...  sent-recovery_rate
# 5926                                               None  sent-recovery_rate
# 5927                                               None  sent-recovery_rate
#
# [4367 rows x 4 columns]
# 5 sent-infectiousness_period
#              pid                                              title sentence  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...     None
# 3     PMC1215526  Macrophages and cytokines in the early defence...     None
# 5     PMC1262710  Molecular signature of clinical severity in re...     None
# 6     PMC1276795  A simple and rapid approach for screening of S...     None
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...     None
# ...          ...                                                ...      ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...     None
# 5924  PMC7299143  Significance of geographical factors to the CO...     None
# 5925  PMC7299147  A new SAIR model on complex networks for analy...     None
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...     None
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...     None
#
#                       match_type
# 0     sent-infectiousness_period
# 3     sent-infectiousness_period
# 5     sent-infectiousness_period
# 6     sent-infectiousness_period
# 8     sent-infectiousness_period
# ...                          ...
# 5923  sent-infectiousness_period
# 5924  sent-infectiousness_period
# 5925  sent-infectiousness_period
# 5926  sent-infectiousness_period
# 5927  sent-infectiousness_period
#
# [4080 rows x 4 columns]
#  55%|█████████████████████████████████████████████▎                                     | 6/11 [00:00<00:00, 15.97it/s]
# 6 sent-case_fatality_rate
#              pid                                              title sentence  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...     None
# 3     PMC1215526  Macrophages and cytokines in the early defence...     None
# 5     PMC1262710  Molecular signature of clinical severity in re...     None
# 6     PMC1276795  A simple and rapid approach for screening of S...     None
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...     None
# ...          ...                                                ...      ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...     None
# 5924  PMC7299143  Significance of geographical factors to the CO...     None
# 5925  PMC7299147  A new SAIR model on complex networks for analy...     None
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...     None
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...     None
#
#                    match_type
# 0     sent-case_fatality_rate
# 3     sent-case_fatality_rate
# 5     sent-case_fatality_rate
# 6     sent-case_fatality_rate
# 8     sent-case_fatality_rate
# ...                       ...
# 5923  sent-case_fatality_rate
# 5924  sent-case_fatality_rate
# 5925  sent-case_fatality_rate
# 5926  sent-case_fatality_rate
# 5927  sent-case_fatality_rate
#
# [4538 rows x 4 columns]
# 7 sent-hospitalized_proportion
#              pid                                              title sentence  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...     None
# 3     PMC1215526  Macrophages and cytokines in the early defence...     None
# 5     PMC1262710  Molecular signature of clinical severity in re...     None
# 6     PMC1276795  A simple and rapid approach for screening of S...     None
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...     None
# ...          ...                                                ...      ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...     None
# 5924  PMC7299143  Significance of geographical factors to the CO...     None
# 5925  PMC7299147  A new SAIR model on complex networks for analy...     None
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...     None
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...     None
#
#                         match_type
# 0     sent-hospitalized_proportion
# 3     sent-hospitalized_proportion
# 5     sent-hospitalized_proportion
# 6     sent-hospitalized_proportion
# 8     sent-hospitalized_proportion
# ...                            ...
# 5923  sent-hospitalized_proportion
# 5924  sent-hospitalized_proportion
# 5925  sent-hospitalized_proportion
# 5926  sent-hospitalized_proportion
# 5927  sent-hospitalized_proportion
#
# [4080 rows x 4 columns]
#  73%|████████████████████████████████████████████████████████████▎                      | 8/11 [00:00<00:00, 16.13it/s]
# 8 sent-asymptomatic_fraction
#              pid                                              title sentence  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...     None
# 3     PMC1215526  Macrophages and cytokines in the early defence...     None
# 5     PMC1262710  Molecular signature of clinical severity in re...     None
# 6     PMC1276795  A simple and rapid approach for screening of S...     None
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...     None
# ...          ...                                                ...      ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...     None
# 5924  PMC7299143  Significance of geographical factors to the CO...     None
# 5925  PMC7299147  A new SAIR model on complex networks for analy...     None
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...     None
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...     None
#
#                       match_type
# 0     sent-asymptomatic_fraction
# 3     sent-asymptomatic_fraction
# 5     sent-asymptomatic_fraction
# 6     sent-asymptomatic_fraction
# 8     sent-asymptomatic_fraction
# ...                          ...
# 5923  sent-asymptomatic_fraction
# 5924  sent-asymptomatic_fraction
# 5925  sent-asymptomatic_fraction
# 5926  sent-asymptomatic_fraction
# 5927  sent-asymptomatic_fraction
#
# [4071 rows x 4 columns]
# 9 sent-hospitalized_fraction
#              pid                                              title sentence  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...     None
# 3     PMC1215526  Macrophages and cytokines in the early defence...     None
# 5     PMC1262710  Molecular signature of clinical severity in re...     None
# 6     PMC1276795  A simple and rapid approach for screening of S...     None
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...     None
# ...          ...                                                ...      ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...     None
# 5924  PMC7299143  Significance of geographical factors to the CO...     None
# 5925  PMC7299147  A new SAIR model on complex networks for analy...     None
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...     None
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...     None
#
#                       match_type
# 0     sent-hospitalized_fraction
# 3     sent-hospitalized_fraction
# 5     sent-hospitalized_fraction
# 6     sent-hospitalized_fraction
# 8     sent-hospitalized_fraction
# ...                          ...
# 5923  sent-hospitalized_fraction
# 5924  sent-hospitalized_fraction
# 5925  sent-hospitalized_fraction
# 5926  sent-hospitalized_fraction
# 5927  sent-hospitalized_fraction
#
# [4061 rows x 4 columns]
#  91%|██████████████████████████████████████████████████████████████████████████▌       | 10/11 [00:00<00:00, 16.41it/s]
# 10 sent-asymptomatic_ratio
#              pid                                              title sentence  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...     None
# 3     PMC1215526  Macrophages and cytokines in the early defence...     None
# 5     PMC1262710  Molecular signature of clinical severity in re...     None
# 6     PMC1276795  A simple and rapid approach for screening of S...     None
# 8     PMC1298938  Functional and Genetic Analysis of Coronavirus...     None
# ...          ...                                                ...      ...
# 5923  PMC7298926  Impacts of epidemic outbreaks on supply chains...     None
# 5924  PMC7299143  Significance of geographical factors to the CO...     None
# 5925  PMC7299147  A new SAIR model on complex networks for analy...     None
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...     None
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...     None
#
#                    match_type
# 0     sent-asymptomatic_ratio
# 3     sent-asymptomatic_ratio
# 5     sent-asymptomatic_ratio
# 6     sent-asymptomatic_ratio
# 8     sent-asymptomatic_ratio
# ...                       ...
# 5923  sent-asymptomatic_ratio
# 5924  sent-asymptomatic_ratio
# 5925  sent-asymptomatic_ratio
# 5926  sent-asymptomatic_ratio
# 5927  sent-asymptomatic_ratio
#
# [4067 rows x 4 columns]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 16.39it/s]

# %%
explode_df = pd.concat(exploded_df_list)

# %%
explode_df.shape
# Out:
# (48466, 4)

# %%
print(f"Number of unique pids: {explode_df.pid.unique().shape}")
# Out:
# Number of unique pids: (4054,)

# %%
explode_df.pid.unique().shape
# Out:
# (4054,)

# %%
explode_df[explode_df.pid.isin(covid_papers)]
# Out:
#              pid                                              title  \
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
# 2719  PMC7121484  Early Transmission Dynamics in Wuhan, China, o...
# 4528  PMC7186508  To mask or not to mask: Modeling the potential...
#
#                                                sentence  \
# 2719  the incubation period distribution (i.e., the ...
# 2719  we used an informative prior distribution for ...
# 2719  we examined data on exposures among 10 confirm...
# 2719  our preliminary estimate of the incubation per...
# 4528  additionally, η accounts for the relative infe...
# 2719                                               None
# 4528                                               None
# 2719                                               None
# 4528  unsurprisingly, the greater the proportion of ...
# 4528  unsurprisingly, this benefit is greater if a l...
# 2719                                               None
# 4528                                               None
# 2719                                               None
# 4528  additionally, η accounts for the relative infe...
# 2719                                               None
# 4528  additionally, η accounts for the relative infe...
# 2719                                               None
# 4528                                               None
# 2719                                               None
# 4528                                               None
# 2719                                               None
# 4528  additionally, η accounts for the relative infe...
# 2719                                               None
# 4528  we assume that some fraction of symptomatic in...
# 4528  additionally, η accounts for the relative infe...
# 4528  we find that a small delay in mask adoption (w...
# 2719                                               None
# 4528                                               None
#
#                         match_type
# 2719        sent-incubation_period
# 2719        sent-incubation_period
# 2719        sent-incubation_period
# 2719        sent-incubation_period
# 4528        sent-incubation_period
# 2719            sent-latent_period
# 4528            sent-latent_period
# 2719  sent-asymptomatic_proportion
# 4528  sent-asymptomatic_proportion
# 4528  sent-asymptomatic_proportion
# 2719      sent-case_fatality_ratio
# 4528      sent-case_fatality_ratio
# 2719            sent-recovery_rate
# 4528            sent-recovery_rate
# 2719    sent-infectiousness_period
# 4528    sent-infectiousness_period
# 2719       sent-case_fatality_rate
# 4528       sent-case_fatality_rate
# 2719  sent-hospitalized_proportion
# 4528  sent-hospitalized_proportion
# 2719    sent-asymptomatic_fraction
# 4528    sent-asymptomatic_fraction
# 2719    sent-hospitalized_fraction
# 4528    sent-hospitalized_fraction
# 4528    sent-hospitalized_fraction
# 4528    sent-hospitalized_fraction
# 2719       sent-asymptomatic_ratio
# 4528       sent-asymptomatic_ratio

# %%
pd.isna(None)
# Out:
# True

# %%
explode_df = explode_df[~explode_df.sentence.isna()]

# %%
explode_df.shape
# Out:
# (8873, 4)

# %%
explode_df.pid.unique().shape
# Out:
# (4054,)

# %%
explode_df
# Out:
#              pid                                              title  \
# 0     PMC1074749  Species-independent detection of RNA virus by ...
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 6     PMC1276795  A simple and rapid approach for screening of S...
# 10    PMC1435987  Prions Adhere to Soil Minerals and Remain Infe...
# 10    PMC1435987  Prions Adhere to Soil Minerals and Remain Infe...
# ...          ...                                                ...
# 5794  PMC7283745  Estimation of the basic reproduction number, a...
# 5849  PMC7290384  Forecasting COVID-19-Associated Hospitalizatio...
# 5870  PMC7292581  SARS-CoV-2 shedding and seroconversion among p...
# 5871  PMC7292610  COVID-19 in patients with thoracic malignancie...
# 5902  PMC7295852  ESMO Management and treatment adapted recommen...
#
#                                                sentence  \
# 0     after the mixture was heated to 99°c for 4 min...
# 5     after an incubation period from 2 to 10 days, ...
# 6     the thermal profile consists of an initial inc...
# 10    the sedimented fraction of these control sampl...
# 10    the 10-d increase in incubation period for mte...
# ...                                                 ...
# 5794  let r\na = c\na/c be the ratio of asymptomatic...
# 5849  more specifically, we assumed that the ratio o...
# 5870  despite the positive clinical findings, six of...
# 5871  one patient required icu admission and three p...
# 5902  during the pandemic outbreak, mammography-base...
#
#                    match_type
# 0      sent-incubation_period
# 5      sent-incubation_period
# 6      sent-incubation_period
# 10     sent-incubation_period
# 10     sent-incubation_period
# ...                       ...
# 5794  sent-asymptomatic_ratio
# 5849  sent-asymptomatic_ratio
# 5870  sent-asymptomatic_ratio
# 5871  sent-asymptomatic_ratio
# 5902  sent-asymptomatic_ratio
#
# [8873 rows x 4 columns]

# %%
explode_df.sentence.str.len()
# Out:
# 0        302
# 5        135
# 6        234
# 10       201
# 10       228
#         ...
# 5794      89
# 5849     170
# 5870     195
# 5871    2160
# 5902     414
# Name: sentence, Length: 8873, dtype: int64

# %%
(pd.DataFrame(explode_df.match_type
    .value_counts(dropna=False))
    .reset_index()
    .rename({'index': 'keyword', 'match_type': 'sentence_count'}, axis='columns')
    .merge(pd.DataFrame(sent_cols), left_on="keyword", right_on=0, how="outer").drop(0, axis="columns")
)
# Out:
#                          keyword  sentence_count
# 0         sent-incubation_period            5183
# 1        sent-case_fatality_rate            1550
# 2             sent-recovery_rate             753
# 3   sent-asymptomatic_proportion             402
# 4             sent-latent_period             309
# 5       sent-case_fatality_ratio             212
# 6   sent-hospitalized_proportion             183
# 7     sent-infectiousness_period             102
# 8     sent-asymptomatic_fraction              74
# 9        sent-asymptomatic_ratio              73
# 10    sent-hospitalized_fraction              32

# %%
print(explode_df.shape)
# Out:
# (8873, 4)

# %%
# incubation period + day
incubation_period_day = explode_df[(explode_df.match_type == "sent-incubation_period") & (explode_df.sentence.str.contains('day|days', regex=True))]
incubation_period_day["match_type"] = "sent-incubation_period_day"
incubation_period_day
# Out:
# <ipython-input-213-607dd86fb420>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   incubation_period_day["match_type"] = "sent-incubation_period_day"
#              pid                                              title  \
# 5     PMC1262710  Molecular signature of clinical severity in re...
# 15    PMC1562405  Factors associated with nosocomial SARS-CoV tr...
# 15    PMC1562405  Factors associated with nosocomial SARS-CoV tr...
# 17    PMC1618839  A super-spreading ewe infects hundreds with Q ...
# 17    PMC1618839  A super-spreading ewe infects hundreds with Q ...
# ...          ...                                                ...
# 5921  PMC7298562  Olfactory and Oral Manifestations of COVID-19:...
# 5921  PMC7298562  Olfactory and Oral Manifestations of COVID-19:...
# 5924  PMC7299143  Significance of geographical factors to the CO...
# 5926  PMC7299369  Current Perspective of Antiviral Strategies ag...
# 5927  PMC7299399  Toward Nanotechnology-Enabled Approaches again...
#
#                                                sentence  \
# 5     after an incubation period from 2 to 10 days, ...
# 15    inclusion and exclusion criteria for study cas...
# 15    the estimated 6 day incubation period is based...
# 17    taking may 4, 2003 as the day of exposure for ...
# 17    the point-source nature of the outbreak permit...
# ...                                                 ...
# 5921  estimated incubation period was calculated as ...
# 5921  statistical data and figures were analyzed usi...
# 5924  this contact transmissible disease has an aver...
# 5926  in most patients, the median time of incubatio...
# 5927  the severity of disease in patients depends ma...
#
#                       match_type
# 5     sent-incubation_period_day
# 15    sent-incubation_period_day
# 15    sent-incubation_period_day
# 17    sent-incubation_period_day
# 17    sent-incubation_period_day
# ...                          ...
# 5921  sent-incubation_period_day
# 5921  sent-incubation_period_day
# 5924  sent-incubation_period_day
# 5926  sent-incubation_period_day
# 5927  sent-incubation_period_day
#
# [2485 rows x 4 columns]

# %%
incubation_period_day.shape
# Out:
# (2485, 4)

# %%
#explode_df = explode_df[explode_df.match_type != "sent-incubation_period"]
#explode_df

# %%
explode_df.shape
# Out:
# (8873, 4)

# %%
incubation_period_day.match_type.value_counts(dropna=False)
# Out:
# sent-incubation_period_day    2485
# Name: match_type, dtype: int64

# %%
explode_df.match_type.value_counts(dropna=False)
# Out:
# sent-incubation_period          5183
# sent-case_fatality_rate         1550
# sent-recovery_rate               753
# sent-asymptomatic_proportion     402
# sent-latent_period               309
# sent-case_fatality_ratio         212
# sent-hospitalized_proportion     183
# sent-infectiousness_period       102
# sent-asymptomatic_fraction        74
# sent-asymptomatic_ratio           73
# sent-hospitalized_fraction        32
# Name: match_type, dtype: int64

# %%
combined = pd.concat([incubation_period_day, explode_df], ignore_index=True)

# %%
print(combined.shape)
# Out:
# (11358, 4)

# %%
# recount table above
(pd.DataFrame(combined.match_type
    .value_counts(dropna=False))
    .reset_index()
    .rename({'index': 'keyword', 'match_type': 'sentence_count'}, axis='columns')
    .merge(pd.DataFrame(sent_cols), left_on="keyword", right_on=0, how="outer").drop(0, axis="columns")
)
# Out:
#                          keyword  sentence_count
# 0         sent-incubation_period            5183
# 1     sent-incubation_period_day            2485
# 2        sent-case_fatality_rate            1550
# 3             sent-recovery_rate             753
# 4   sent-asymptomatic_proportion             402
# 5             sent-latent_period             309
# 6       sent-case_fatality_ratio             212
# 7   sent-hospitalized_proportion             183
# 8     sent-infectiousness_period             102
# 9     sent-asymptomatic_fraction              74
# 10       sent-asymptomatic_ratio              73
# 11    sent-hospitalized_fraction              32
